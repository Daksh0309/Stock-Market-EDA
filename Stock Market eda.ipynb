# %%
# !pip install yfinance --quiet

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import yfinance as yf

tickers = ['TCS.NS', 'INFY.NS', 'RELIANCE.NS']

data = yf.download(tickers, start='2023-01-01', end='2024-12-31', auto_adjust=True)['Close']

print("✅ Live data loaded!")
print(data.tail())  # shows latest prices
# Out:
# [*********************100%***********************]  3 of 3 completed
# ✅ Live data loaded!
# Ticker          INFY.NS  RELIANCE.NS       TCS.NS
# Date
# 2024-12-23  1868.988525  1217.437744  3946.769531
# 2024-12-24  1854.176880  1217.885864  3966.892334
# 2024-12-26  1852.574341  1211.710571  3957.021240
# 2024-12-27  1861.655518  1216.192749  3952.987061
# 2024-12-30  1851.214600  1205.883789  3947.244629

# %%
plt.figure(figsize=(14,6))
for col in data.columns:
    plt.plot(data.index, data[col], label=col)

plt.title('Live Stock Price Comparison')
plt.xlabel('Date')
plt.ylabel('Price (INR)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
